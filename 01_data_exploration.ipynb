# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Display settings
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)

# For better plots
# %matplotlib inline
plt.style.use('ggplot')

print("✅ Libraries imported successfully!")
# Out:
# ✅ Libraries imported successfully!

# %%
print("Loading dataset... (this may take 10-20 seconds)")

df = pd.read_csv('../data/creditcard.csv')

print("✅ Dataset loaded successfully!")
print(f"\nDataset shape: {df.shape}")
print(f"Total transactions: {df.shape[0]:,}")
print(f"Total features: {df.shape[1]}")
# Out:
# Loading dataset... (this may take 10-20 seconds)
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 3
#       1 print("Loading dataset... (this may take 10-20 seconds)")
# ----> 3 df = pd.read_csv('../data/creditcard.csv')
#       5 print("✅ Dataset loaded successfully!")
#       6 print(f"\nDataset shape: {df.shape}")
#
# ...

# %%
print("Loading dataset... (this may take 10-20 seconds)")

df = pd.read_csv('C:\Users\DIPTESH-PC\credit_card_fraud\data\creditcard.csv')

print("✅ Dataset loaded successfully!")
print(f"\nDataset shape: {df.shape}")
print(f"Total transactions: {df.shape[0]:,}")
print(f"Total features: {df.shape[1]}")
# Out:
#   Cell In[3], line 3
#     df = pd.read_csv('C:\Users\DIPTESH-PC\credit_card_fraud\data\creditcard.csv')
#                      ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
print("Loading dataset... (this may take 10-20 seconds)")

df = pd.read_csv('\data\creditcard.csv')

print("✅ Dataset loaded successfully!")
print(f"\nDataset shape: {df.shape}")
print(f"Total transactions: {df.shape[0]:,}")
print(f"Total features: {df.shape[1]}")
# Out:
# Loading dataset... (this may take 10-20 seconds)
# <>:3: SyntaxWarning: invalid escape sequence '\d'
# <>:3: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\DIPTESH-PC\AppData\Local\Temp\ipykernel_15164\4291959036.py:3: SyntaxWarning: invalid escape sequence '\d'
#   df = pd.read_csv('\data\creditcard.csv')
# C:\Users\DIPTESH-PC\AppData\Local\Temp\ipykernel_15164\4291959036.py:3: SyntaxWarning: invalid escape sequence '\d'
#   df = pd.read_csv('\data\creditcard.csv')
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 3
#       1 print("Loading dataset... (this may take 10-20 seconds)")
# ----> 3 df = pd.read_csv('\data\creditcard.csv')
#       5 print("✅ Dataset loaded successfully!")
#       6 print(f"\nDataset shape: {df.shape}")
#
# ...

# %%
print("Loading dataset... (this may take 10-20 seconds)")

df = pd.read_csv('../data/creditcard.csv')

print("✅ Dataset loaded successfully!")
print(f"\nDataset shape: {df.shape}")
print(f"Total transactions: {df.shape[0]:,}")
print(f"Total features: {df.shape[1]}")
# Out:
# Loading dataset... (this may take 10-20 seconds)
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 3
#       1 print("Loading dataset... (this may take 10-20 seconds)")
# ----> 3 df = pd.read_csv('../data/creditcard.csv')
#       5 print("✅ Dataset loaded successfully!")
#       6 print(f"\nDataset shape: {df.shape}")
#
# ...

# %%
import os

# Let's see your exact folder structure
print("Current working directory:")
print(os.getcwd())

print("\n" + "="*50)
print("Checking folder structure...")
print("="*50)

# Check if we're in the notebooks folder
if 'notebooks' in os.getcwd():
    print("✅ You're in the notebooks folder (correct location)")
    print("\nLooking for data folder one level up...")
    
    # Check if data folder exists
    if os.path.exists('../data'):
        print("✅ Data folder found!")
        
        # List files in data folder
        print("\nFiles in data folder:")
        files = os.listdir('../data')
        for f in files:
            print(f"  - {f}")
            
        # Check specifically for creditcard.csv
        if 'creditcard.csv' in files:
            print("\n✅ creditcard.csv is in the data folder!")
            print("The path '../data/creditcard.csv' should work.")
        else:
            print("\n❌ creditcard.csv not found in data folder")
            print("Files found:", files)
    else:
        print("❌ Data folder not found at '../data'")
else:
    print("⚠️ You're NOT in the notebooks folder")
    print("Current location:", os.getcwd())
# Out:
# Current working directory:
# C:\Users\DIPTESH-PC\credit_card_fraud
#
# ...
# Checking folder structure...
# ...
# ⚠️ You're NOT in the notebooks folder
# Current location: C:\Users\DIPTESH-PC\credit_card_fraud

# %%
import pandas as pd

print("Loading dataset...")

# Load the data
df = pd.read_csv('../data/creditcard.csv')

print("✅ Dataset loaded successfully!")
print(f"\nDataset shape: {df.shape}")
print(f"Total transactions: {df.shape[0]:,}")
print(f"Total features: {df.shape[1]}")

# Show first few rows
print("\nFirst 3 rows:")
df.head(3)
# Out:
# Loading dataset...
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 6
#       3 print("Loading dataset...")
#       5 # Load the data
# ----> 6 df = pd.read_csv('../data/creditcard.csv')
#       8 print("✅ Dataset loaded successfully!")
#       9 print(f"\nDataset shape: {df.shape}")
#
# ...

# %%
import pandas as pd

print("Loading dataset...")

# Load the data
df = pd.read_csv('data/creditcard.csv')

print("✅ Dataset loaded successfully!")
print(f"\nDataset shape: {df.shape}")
print(f"Total transactions: {df.shape[0]:,}")
print(f"Total features: {df.shape[1]}")

# Show first few rows
print("\nFirst 3 rows:")
df.head(3)
# Out:
# Loading dataset...
# ✅ Dataset loaded successfully!
#
# Dataset shape: (284807, 31)
# Total transactions: 284,807
# Total features: 31
#
# First 3 rows:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169
# 1  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772
# 2  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946
#
#         V15       V16       V17       V18       V19       V20       V21  \
# 0  1.468177 -0.470401  0.207971  0.025791  0.403993  0.251412 -0.018307
# ...
